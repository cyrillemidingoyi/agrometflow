# %%
from agrometflow.metadata import *

# %% [markdown]
# # LIST CLIMATE SOURCES #

# %%
list_clim_products()
# Out:
# ['arc2',
#  'chirps',
#  'cmorphv1',
#  'era5',
#  'imerg',
#  'mswep',
#  'nasapower',
#  'persiann',
#  'rfe2',
#  'tamsat']

# %%
list_sources_for_variable("PR")
# Out:
# {'nasapower': ['power'],
#  'era5': ['cds'],
#  'chirps': ['chc_ucsb_ftp'],
#  'tamsat': ['jasmin_http'],
#  'rfe2': ['noaa_cpc_ftp'],
#  'persiann': ['chrs_ftp'],
#  'mswep': ['gloh2o_drive'],
#  'cmorphv1': ['noaa_cpc_ftp'],
#  'arc2': ['noaa_cpc_ftp'],
#  'imerg': ['nasa_gesdisc_http']}

# %%
get_convert_func("TMAX", "era5", "cds")
# Out:
# <function agrometflow.metadata.<lambda>(x)>

# %%
get_variables_clim_by_source("nasapower")
# ['T2M', 'PRECTOT', 'RH2M']
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 get_variables_clim_by_source("nasapower")
#       2 # ['T2M', 'PRECTOT', 'RH2M']
#
# File /mnt/d/Mes Donnees/TCMP/github/agrometflow/agrometflow/src/agrometflow/metadata.py:598, in get_variables_clim_by_source(source)
#     597 def get_variables_clim_by_source(source):
# --> 598     return _get_variables_by_source(metadata, source, category="climate")
#
# File /mnt/d/Mes Donnees/TCMP/github/agrometflow/agrometflow/src/agrometflow/metadata.py:592, in _get_variables_by_source(metadata, source, category)
#     589         records.append(record)
#     591 if not records:
# --> 592     raise ValueError(f"No {category} variables found for source '{source}'.")
#     594 return pd.DataFrame(records)
#
# ValueError: No climate variables found for source 'nasapower'.

# %%
list_soil_sources()
# Out:
# ['soilgrids']

# %%
get_variables_soil_by_source("soilgrids")
# {'description': 'Mean air temperature at 2 meters', 'units': '°C'}
# Out:
#   variable  name  unit             description
# 0     sand  sand     %           Sand fraction
# 1     clay  clay     %           Clay fraction
# 2      ocd   ocd  g/kg  Organic carbon density

# %%
get_sources_for_clim_variable("T2M")
# Out:
# ['nasapower']

# %%
get_sources_for_soil_variable("sand")
# Out:
# ['soilgrids']
